# %%
from NB_Writer import *

Exam('ECON 0200', 'Example', 'Monday, April 22', ME=False, keep=False)

# %% [markdown]
# Name: _____________________  \hfill Student ID: _____________________

# %% [markdown]
# This Final Exam will take 1 hour and 50 minutes. Exams are designed to both test your knowledge and challenge you to apply familiar concepts in new environments. Treat it as if you're trying to show me that you understand the material. Answer clearly and completely.

# %% [markdown]
# # Academic Conduct Code
#
# The following academic conduct code is designed to protect the integrity of your work, not to make school feel overbearing. Print your name/initials beside the five academic honesty agreements before beginning.

# %% [markdown]
# I pledge to my fellow students, the university and the instructor, that:
#
# ____ I will complete this MiniExam solely using my own work.
#
# ____ I will not use any digital or hardcopy resources unless explicitly allowed by the instructor.
#
# ____ I will not communicate with others about the MiniExam in the room or remotely.
#
# ____ I will not discuss the MiniExam with students who did not take the MiniExam at the same time.

# %% [markdown]
# \pagebreak

# %% [markdown]
# ## Game 1 (of 11). For the following game:
#
# $$
# \begin{array}{lccc}
#     & & & (1-x) \ \ \ \ x\\
#     & & & \text{L} \ \ \ \ \text{R}\\
#     & &
#     \begin{array}{r}
#         y \ \ \text{U} \\
#         (1-y) \ \ \text{D} \\
#     \end{array} &
#     \begin{array}{|c|c|}
#         \hline
#         9,4 & 13,3 \\
#         \hline
#         4,6 & 13,7 \\
#         \hline
#     \end{array}
# \end{array}
# $$

# %% [markdown]
# a) Which outcomes are Pareto optimal (*if none, write "none"*)? \hfill ______________
#
# b) List all NE in pure strategies. \hfill ______________
#
# c) Is this game zero sum? \hfill ______________
#
# d) List all dominant strategies for this game (*if none, write "none"*). \hfill ______________
#
# e) Plot both player’s best responses and all MSNE on the graph below.

# %%
# NB_Writer: \includegraphics[width=\textwidth]
Image('Images/mixed_strategy_graph.png')

# %% [markdown]
# - A
# - Short
# - Unordered
# - List
# - Example

# %% [markdown]
# a) A
# b) Short
# c) Ordered
# d) List
# e) Example

# %% [markdown]
# 1. A
# 2. Short
# 3. Ordered
# 4. List

# %% [markdown]
# ## a. Test
